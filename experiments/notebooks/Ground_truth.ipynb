# %% [markdown]
# # **Q1.1**

# %%
# !python Q1-1.py --target /users/Minqiu/parsed-logs-2025-1/1/3122112-2552850857417903032.txt \
    --dir /users/Minqiu/parsed-logs-2025-1 \
    --filter_by exe
# Out:
# Target file: /users/Minqiu/parsed-logs-2025-1/1/3122112-2552850857417903032.txt
#   exe: 4068766220
#   total_bytes: 20259556
#   nprocs: 4
#   jobid: 3122112
#   Total BW (MiB/s): 24.62138738920531
#   Total IOPS: 160770.9707222275
#   POSIX - BW (MiB/s): 134.75626248797653, IOPS: 17855.32434909535
#   STDIO - BW (MiB/s): 20.325598507493833, IOPS: 166345.3670627302
#   MPIIO - BW (MiB/s): None, IOPS: None
#
# Searched 27 directories under: /users/Minqiu/parsed-logs-2025-1
# Filter by: exe
# Parsed jobs: 22246
# Candidates after filter: 3574
# Results (excluding target): 3573
#
# === Results ===
# path=/users/Minqiu/parsed-logs-2025-1/8/3122715-1780708592793542245.txt	jobid=3122715	exe=4068766220	nprocs=4	total_bytes=17525885	Total_BW_MiB_s=368.9784625544075	Total_IOPS=163671.68528411852	POSIX_BW=986.673652510073	POSIX_IOPS=130349.23757993113	STDIO_BW=308.0658548138241	STDIO_IOPS=166957.70275514165	MPIIO_BW=None	MPIIO_IOPS=None
# ...

# %% [markdown]
# # **Q1.2**

# %%
# !python Q1-2.py \
  --target /users/Minqiu/parsed-logs-2025-1/1/3122112-2552850857417903032.txt \
  --dir /users/Minqiu/parsed-logs-2025-1 \
  --filter_by fs
# Out:
# === Target ===
# Target file: /users/Minqiu/parsed-logs-2025-1/1/3122112-2552850857417903032.txt
#   path: /users/Minqiu/parsed-logs-2025-1/1/3122112-2552850857417903032.txt
#   jobid: 3122112
#   exe: 4068766220
#   nprocs: 4
#   fs_type: lustre  mount_pt: /home
#   total_bytes: 20259556
#   Total BW (MiB/s): 24.62138738920531
#   Total IOPS: 160770.9707222275
#   POSIX - BW (MiB/s): 134.75626248797653, IOPS: 17855.32434909535
#   STDIO - BW (MiB/s): 20.325598507493833, IOPS: 166345.3670627302
#   MPIIO - BW (MiB/s): None, IOPS: None
#
# Filter by: fs
# Parsed jobs: 24908
# Candidates after filter: 4122
#
# === Results ===
# path=/users/Minqiu/parsed-logs-2025-1/8/3122715-1780708592793542245.txt	jobid=3122715	exe=4068766220	nprocs=4	fs_type=lustre	total_bytes=17525885	Total_BW_MiB_s=368.9784625544075	Total_IOPS=163671.68528411852	POSIX_BW=986.673652510073	POSIX_IOPS=130349.23757993113	STDIO_BW=308.0658548138241	STDIO_IOPS=166957.70275514165	MPIIO_BW=None	MPIIO_IOPS=None
# ...

# %% [markdown]
# # **Q1.3 & Q1.4**

# %%
# !python Q1-3.py \
    --target /users/Minqiu/parsed-logs-2025-1/1/3122112-2552850857417903032.txt \
    --dir /users/Minqiu/parsed-logs-2025-1
# Out:
# Target file: /users/Minqiu/parsed-logs-2025-1/1/3122112-2552850857417903032.txt
#   exe: 4068766220
#   total_bytes: 4162621
#   nprocs: 4
#   jobid: 3122112
#   I/O Phases - Open ratio: 0.5631229235880398, Read ratio: 0.4368770764119601, Write ratio: 0.0
#   Avg request size: 7913.72813688213
#   Open/Stat/Seek ratio: 0.00017416911124024985
#   Rank imbalance (Gini): 0.75
#
# Searched 27 directories under: /users/Minqiu/parsed-logs-2025-1
# Filter by: exe (application name)
# Parsed jobs: 24908
# Candidates after filter (same exe): 3574
# Results (excluding target): 3573
#
# === Results ===
# path=/users/Minqiu/parsed-logs-2025-1/8/3122715-1780708592793542245.txt	jobid=3122715	exe=4068766220	nprocs=4	total_bytes=4206693	open_ratio=0.5627062706270627	read_ratio=0.4372937293729373	write_ratio=0.0	avg_req_size=7937.156603773585	open_stat_seek_ratio=0.0001742461358601638	rank_imbalance_gini=0.75
# ...
